# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("darkgrid")

# %%
df = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   ACCIDENT DATE ACCIDENT TIME BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0    07/27/2019         17:50     NaN      NaN  40.829155 -73.937280
# 1    08/17/2019         18:45     NaN      NaN  40.761550 -73.966590
# 2    08/05/2019         10:00     NaN      NaN  40.685350 -74.001010
# 3    08/20/2019          1:00     NaN      NaN  40.692450 -73.811005
# 4    07/27/2019         10:24     NaN      NaN        NaN        NaN
#
#                       LOCATION                    ON STREET NAME  \
# 0  POINT (-73.93728 40.829155)  WEST 155 STREET
# 1   POINT (-73.96659 40.76155)  3 AVENUE
# 2   POINT (-74.00101 40.68535)  HICKS STREET
# 3  POINT (-73.811005 40.69245)  VAN WYCK EXPWY
# 4                          NaN  BOSTON ROAD
#
#   CROSS STREET NAME OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# 0               NaN             NaN  ...  Driver Inattention/Distraction
# 1               NaN             NaN  ...                     Unspecified
# ...

# %%
df.columns
# Out:
# Index(['ACCIDENT DATE', 'ACCIDENT TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606804 entries, 0 to 1606803
# Data columns (total 29 columns):
# ACCIDENT DATE                    1606804 non-null object
# ACCIDENT TIME                    1606804 non-null object
# BOROUGH                          1119529 non-null object
# ZIP CODE                         1119332 non-null object
# LATITUDE                         1410385 non-null float64
# LONGITUDE                        1410385 non-null float64
# LOCATION                         1410385 non-null object
# ON STREET NAME                   1291889 non-null object
# CROSS STREET NAME                1068894 non-null object
# OFF STREET NAME                  222750 non-null object
# NUMBER OF PERSONS INJURED        1606787 non-null float64
# NUMBER OF PERSONS KILLED         1606773 non-null float64
# NUMBER OF PEDESTRIANS INJURED    1606804 non-null int64
# NUMBER OF PEDESTRIANS KILLED     1606804 non-null int64
# ...

# %%
df['ACCIDENT DATE'].dtype
# Out:
# dtype('O')

# %%
df['ACCIDENT DATE'] =  pd.to_datetime(df['ACCIDENT DATE'])

# %%
df[df['ACCIDENT DATE'] > '2016-12-31']
# Out:
#        ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0         2019-07-27         17:50        NaN      NaN  40.829155 -73.937280
# 1         2019-08-17         18:45        NaN      NaN  40.761550 -73.966590
# 2         2019-08-05         10:00        NaN      NaN  40.685350 -74.001010
# 3         2019-08-20          1:00        NaN      NaN  40.692450 -73.811005
# 4         2019-07-27         10:24        NaN      NaN        NaN        NaN
# ...              ...           ...        ...      ...        ...        ...
# 704759    2017-03-24         19:30   BROOKLYN    11219  40.624653 -73.999330
# 704760    2017-03-14         22:17        NaN      NaN  40.688988 -73.845910
# 704761    2017-03-14         18:12  MANHATTAN    10032  40.834858 -73.946724
# 704762    2017-03-21         15:00        NaN      NaN  40.788055 -73.944330
# 704763    2017-03-16         15:35  MANHATTAN    10007  40.714478 -74.013540
#
# ...

# %%
df = df[df['ACCIDENT DATE'] > '2016-12-31']

# %%
df[df['ACCIDENT DATE']<'2017-03-16']
# Out:
#        ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 190200    2017-02-03         21:40        NaN      NaN  40.761400 -73.795100
# 192743    2017-02-24         15:30        NaN      NaN  40.664856 -73.880230
# 562104    2017-03-15         12:45  MANHATTAN    10001        NaN        NaN
# 562156    2017-03-15         13:30        NaN      NaN        NaN        NaN
# 562182    2017-03-15         14:20        NaN      NaN        NaN        NaN
# ...              ...           ...        ...      ...        ...        ...
# 704754    2017-03-10         10:45   BROOKLYN    11201  40.689434 -73.991630
# 704757    2017-03-04          0:00     QUEENS    11103  40.761684 -73.912370
# 704758    2017-03-13         20:00      BRONX    10469  40.871895 -73.847890
# 704760    2017-03-14         22:17        NaN      NaN  40.688988 -73.845910
# 704761    2017-03-14         18:12  MANHATTAN    10032  40.834858 -73.946724
#
# ...

# %%
len(df)
# Out:
# 648991

# %%
df=df[['ACCIDENT DATE','ACCIDENT TIME','BOROUGH','ZIP CODE','NUMBER OF PERSONS INJURED',
       'NUMBER OF PEDESTRIANS INJURED','NUMBER OF CYCLIST INJURED','NUMBER OF MOTORIST INJURED']]

# %%
df
# Out:
#        ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE  \
# 0         2019-07-27         17:50        NaN      NaN
# 1         2019-08-17         18:45        NaN      NaN
# 2         2019-08-05         10:00        NaN      NaN
# 3         2019-08-20          1:00        NaN      NaN
# 4         2019-07-27         10:24        NaN      NaN
# ...              ...           ...        ...      ...
# 704759    2017-03-24         19:30   BROOKLYN    11219
# 704760    2017-03-14         22:17        NaN      NaN
# 704761    2017-03-14         18:12  MANHATTAN    10032
# 704762    2017-03-21         15:00        NaN      NaN
# 704763    2017-03-16         15:35  MANHATTAN    10007
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 0                             0.0                              0
# 1                             0.0                              0
# 2                             0.0                              0
# ...

# %%
def getmonth(month):
    
    month = str(month).split('-')[1]
    month=month[:2]
    
    if month == '01':
        month='January'
    elif month == '02':
        month='February'
    elif month == '03':
        month='March'
    elif month == '04':
        month='April'
    elif month == '05':
        month='May'
    elif month == '06':
        month='June'
    elif month == '07':
        month='July'
    elif month == '08':
        month='August'
    elif month == '09':
        month='September'
    elif month == '10':
        month='October'
    elif month == '11':
        month='November'
    elif month == '12':
        month='December'
    
    return month

# %%
#str(df[df['accident_date']=='2018-11-04']['accident_date'].iloc[:1]).split('-')[1]

# %%
df['MONTH']= df['ACCIDENT DATE'].apply(getmonth)

# %%
#df[df['month']=='January']

# %%
def gethour(time):
    
    time = int(time.split(':')[0])
    
    if time < 12 and time > 0:
        time = str(time) + " AM"
    
    if time ==12:
        time = "12 PM"
    
    if time ==13:
        time = "1 PM"
    
    elif time ==14:
        time = "2 PM"
    
    elif time ==15:
        time = "3 PM"
    
    elif time ==16:
        time = "4 PM"
    
    elif time ==17:
        time = "5 PM"
    
    elif time ==18:
        time = "6 PM"
    
    elif time ==19:
        time = "7 PM"
    
    elif time ==20:
        time = "8 PM"
    
    elif time ==21:
        time = "9 PM"
    
    elif time ==22:
        time = "10 PM"
    
    elif time ==23:
        time = "11 PM"
    
    elif time ==24:
        time = "12 PM"
       
    elif time ==0:
        time = "12 AM"
    
    
    return time

# %%
df['HOUR'] = df['ACCIDENT TIME'].apply(gethour)

# %%
df
# Out:
#        ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE  \
# 0         2019-07-27         17:50        NaN      NaN
# 1         2019-08-17         18:45        NaN      NaN
# 2         2019-08-05         10:00        NaN      NaN
# 3         2019-08-20          1:00        NaN      NaN
# 4         2019-07-27         10:24        NaN      NaN
# ...              ...           ...        ...      ...
# 704759    2017-03-24         19:30   BROOKLYN    11219
# 704760    2017-03-14         22:17        NaN      NaN
# 704761    2017-03-14         18:12  MANHATTAN    10032
# 704762    2017-03-21         15:00        NaN      NaN
# 704763    2017-03-16         15:35  MANHATTAN    10007
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 0                             0.0                              0
# 1                             0.0                              0
# 2                             0.0                              0
# ...

# %%
df['DAY OF WEEK'] = df['ACCIDENT DATE'].dt.day_name()

# %%
df
# Out:
#        ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE  \
# 0         2019-07-27         17:50        NaN      NaN
# 1         2019-08-17         18:45        NaN      NaN
# 2         2019-08-05         10:00        NaN      NaN
# 3         2019-08-20          1:00        NaN      NaN
# 4         2019-07-27         10:24        NaN      NaN
# ...              ...           ...        ...      ...
# 704759    2017-03-24         19:30   BROOKLYN    11219
# 704760    2017-03-14         22:17        NaN      NaN
# 704761    2017-03-14         18:12  MANHATTAN    10032
# 704762    2017-03-21         15:00        NaN      NaN
# 704763    2017-03-16         15:35  MANHATTAN    10007
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 0                             0.0                              0
# 1                             0.0                              0
# 2                             0.0                              0
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#        ACCIDENT DATE ACCIDENT TIME        BOROUGH ZIP CODE  \
# 5         2019-08-19         11:06          BRONX    10465
# 6         2019-08-21         19:15      MANHATTAN    10018
# 8         2019-07-24         12:30      MANHATTAN    10035
# 9         2019-08-11          1:12      MANHATTAN    10018
# 10        2019-08-10         16:44  STATEN ISLAND    10310
# ...              ...           ...            ...      ...
# 704757    2017-03-04          0:00         QUEENS    11103
# 704758    2017-03-13         20:00          BRONX    10469
# 704759    2017-03-24         19:30       BROOKLYN    11219
# 704761    2017-03-14         18:12      MANHATTAN    10032
# 704763    2017-03-16         15:35      MANHATTAN    10007
#
#         NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 5                             3.0                              0
# 6                             0.0                              0
# ...

# %%
df = df.rename(columns={"ACCIDENT DATE": "accident_date", "ACCIDENT TIME": "accident_time", "BOROUGH":"borough",
                  "ZIP CODE": "zip_code","NUMBER OF PERSONS INJURED":"total_injuries","NUMBER OF PEDESTRIANS INJURED":
                   "pedestrians","NUMBER OF CYCLIST INJURED":"cyclists","NUMBER OF MOTORIST INJURED":"motorists",     
                    "MONTH":"month","HOUR":"hour", "DAY OF WEEK":"day_of_week"})

# %%
df.iloc[-1:]
# Out:
#        accident_date accident_time    borough zip_code  total_injuries  \
# 704763    2017-03-16         15:35  MANHATTAN    10007             0.0
#
#         pedestrians  cyclists  motorists  month  hour day_of_week
# 704763            0         0          0  March  3 PM    Thursday

# %%
if df['total_injuries'].iloc[0]>=1 and df['motorists'].iloc[0]>=1:
    print(True)
# Out:
# True

# %%
df['injury_type'] = np.nan

# %%
#df[['pedestrians']][1]

# %%
df.loc[df['pedestrians']>=1,'injury_type']='Pedestrian'
df.loc[df['cyclists']>=1,'injury_type']='Cyclist'
df.loc[df['motorists']>=1,'injury_type']='Motorist'
df.loc[df['total_injuries']==0,'injury_type']='No Injury'

# %%
df.loc[(df['pedestrians']>=1) & (df['motorists']>=1),'injury_type']='Mixed'
df.loc[(df['pedestrians']>=1) & (df['cyclists']>=1),'injury_type']='Mixed'
df.loc[(df['cyclists']>=1) & (df['motorists']>=1),'injury_type']='Mixed'

# %%
df.head()
# Out:
#    accident_date accident_time        borough zip_code  total_injuries  \
# 5     2019-08-19         11:06          BRONX    10465             3.0
# 6     2019-08-21         19:15      MANHATTAN    10018             0.0
# 8     2019-07-24         12:30      MANHATTAN    10035             1.0
# 9     2019-08-11          1:12      MANHATTAN    10018             0.0
# 10    2019-08-10         16:44  STATEN ISLAND    10310             0.0
#
#     pedestrians  cyclists  motorists   month   hour day_of_week injury_type
# 5             0         0          3  August  11 AM      Monday    Motorist
# 6             0         0          0  August   7 PM   Wednesday   No Injury
# 8             0         0          1    July  12 PM   Wednesday    Motorist
# 9             0         0          0  August   1 AM      Sunday   No Injury
# 10            0         0          0  August   4 PM    Saturday   No Injury

# %%
df['incident'] = 1

# %%
df.head()
# Out:
#    accident_date accident_time        borough zip_code  total_injuries  \
# 5     2019-08-19         11:06          BRONX    10465             3.0
# 6     2019-08-21         19:15      MANHATTAN    10018             0.0
# 8     2019-07-24         12:30      MANHATTAN    10035             1.0
# 9     2019-08-11          1:12      MANHATTAN    10018             0.0
# 10    2019-08-10         16:44  STATEN ISLAND    10310             0.0
#
#     pedestrians  cyclists  motorists   month   hour day_of_week injury_type  \
# 5             0         0          3  August  11 AM      Monday    Motorist
# 6             0         0          0  August   7 PM   Wednesday   No Injury
# 8             0         0          1    July  12 PM   Wednesday    Motorist
# 9             0         0          0  August   1 AM      Sunday   No Injury
# 10            0         0          0  August   4 PM    Saturday   No Injury
#
#     incident
# 5          1
# 6          1
# 8          1
# 9          1
# ...

# %%
df['year'] = df['accident_date'].dt.year

# %%
#df.groupby(['borough','pedestrians']).count().reset_index()

# %%
#df.drop(['level_0', 'index'], axis=1)

# %%
df['hour'].value_counts()
# Out:
# 4 PM     30217
# 5 PM     29615
# 2 PM     29094
# 3 PM     27144
# 6 PM     25571
# 1 PM     24948
# 12 PM    23639
# 8 AM     23133
# 9 AM     22265
# 11 AM    22148
# 10 AM    21006
# 7 PM     20600
# 8 PM     16785
# 9 PM     14394
# 12 AM    14264
# 7 AM     12664
# 10 PM    12647
# 11 PM    10095
# 6 AM      8289
# 1 AM      6063
# 5 AM      4987
# 4 AM      4583
# 2 AM      4539
# 3 AM      4039
# Name: hour, dtype: int64

# %%
#df.to_csv('collisions_cleaned.csv')

# %%
df.to_csv('collisions_cleaned_withclassify.csv',index=False)

# %%
pip install psycopg2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/84/d7/6a93c99b5ba4d4d22daa3928b983cec66df4536ca50b22ce5dcac65e4e71/psycopg2-2.8.4.tar.gz
#     ERROR: Command errored out with exit status 1:
#      command: //anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1g/3nn13nzd2d3_gkbfjtbsj5vr0000gn/T/pip-install-eqmt2f60/psycopg2/setup.py'"'"'; __file__='"'"'/private/var/folders/1g/3nn13nzd2d3_gkbfjtbsj5vr0000gn/T/pip-install-eqmt2f60/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base pip-egg-info
#          cwd: /private/var/folders/1g/3nn13nzd2d3_gkbfjtbsj5vr0000gn/T/pip-install-eqmt2f60/psycopg2/
#     Complete output (23 lines):
#     running egg_info
#     creating pip-egg-info/psycopg2.egg-info
#     writing pip-egg-info/psycopg2.egg-info/PKG-INFO
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
rds_connection_string = "admin:admin@localhost:5432/collisionsdata"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['injuryType_borough',
#  'borough_summary',
#  'injurytype_borough',
#  'month_borough',
#  'weekday_borough',
#  'collisionsdata']

# %%
df.to_sql(name='collisionsdata', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from collisionsdata', con=engine).head()
# Out:
#   accident_date accident_time        borough  zip_code  total_injuries  \
# 0    2019-08-19         11:06          BRONX   10465.0             3.0
# 1    2019-08-21         19:15      MANHATTAN   10018.0             0.0
# 2    2019-07-24         12:30      MANHATTAN   10035.0             1.0
# 3    2019-08-11          1:12      MANHATTAN   10018.0             0.0
# 4    2019-08-10         16:44  STATEN ISLAND   10310.0             0.0
#
#    pedestrians  cyclists  motorists   month   hour day_of_week injury_type  \
# 0            0         0          3  August  11 AM      Monday    Motorist
# 1            0         0          0  August   7 PM   Wednesday   No Injury
# 2            0         0          1    July  12 PM   Wednesday    Motorist
# 3            0         0          0  August   1 AM      Sunday   No Injury
# 4            0         0          0  August   4 PM    Saturday   No Injury
#
#    incident  year
# 0         1  2019
# 1         1  2019
# 2         1  2019
# ...

# %%
injuryType_borough = pd.pivot_table(df,values=['incident'], index=['injury_type'],columns=['borough'],aggfunc=np.sum)

# %%
injuryType_borough.columns = injuryType_borough.columns.get_level_values(1)

# %%
injuryType_borough
# Out:
# borough      BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# injury_type
# Cyclist        968      3770       2800    1895            122
# Mixed           65       172        119      75             10
# Motorist      8202     16207       5580   15426           2302
# No Injury    51203    103883      73641   92163          12644
# Pedestrian    3740      7234       4623    5267            561

# %%
injuryType_borough.reset_index()
# Out:
# borough injury_type  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# 0           Cyclist    968      3770       2800    1895            122
# 1             Mixed     65       172        119      75             10
# 2          Motorist   8202     16207       5580   15426           2302
# 3         No Injury  51203    103883      73641   92163          12644
# 4        Pedestrian   3740      7234       4623    5267            561

# %%
injuryType_borough['injury_type'] = injuryType_borough.index

# %%
injuryType_borough['total_accidents'] = injuryType_borough.sum(axis=1).astype(int)

# %%
injuryType_borough.reset_index(inplace=True,drop=True)

# %%
injuryType_borough.columns
# Out:
# Index(['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND',
#        'injury_type', 'total_accidents'],
#       dtype='object', name='borough')

# %%
injuryType_borough =injuryType_borough[['injury_type','BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND',
       'total_accidents']]

# %%
injuryType_borough.to_sql(name='injurytype_borough', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from injurytype_borough', con=engine).head()
# Out:
#   injury_type  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND  \
# 0     Cyclist    968      3770       2800    1895            122
# 1       Mixed     65       172        119      75             10
# 2    Motorist   8202     16207       5580   15426           2302
# 3   No Injury  51203    103883      73641   92163          12644
# 4  Pedestrian   3740      7234       4623    5267            561
#
#    total_accidents
# 0             9555
# 1              441
# 2            47717
# 3           333534
# 4            21425

# %%
borough_summary = pd.pivot_table(df, values=['incident'],index=['borough'],aggfunc=np.sum)

# %%
borough_summary.reset_index()
# Out:
#          borough  incident
# 0          BRONX     64186
# 1       BROOKLYN    131287
# 2      MANHATTAN     86777
# 3         QUEENS    114838
# 4  STATEN ISLAND     15641

# %%
borough_summary['borough']=borough_summary.index

# %%
borough_summary.reset_index(inplace=True,drop=True)

# %%
borough_summary = borough_summary[['borough','incident']]

# %%
borough_summary =borough_summary.rename(columns={"incident":"number_of_accidents"})

# %%
borough_summary['percentage_of_accidents'] = borough_summary['number_of_accidents'].apply(lambda x: x/
                                            borough_summary['number_of_accidents'].sum())

# %%
borough_summary.to_sql(name='borough_summary', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from borough_summary', con=engine).head()
# Out:
#          borough  number_of_accidents  percentage_of_accidents
# 0          BRONX                64186                 0.155516
# 1       BROOKLYN               131287                 0.318095
# 2      MANHATTAN                86777                 0.210252
# 3         QUEENS               114838                 0.278241
# 4  STATEN ISLAND                15641                 0.037897

# %%
month_borough = pd.pivot_table(df, values=['incident'], index=['month'],columns=['borough'],aggfunc=np.sum)

# %%
month_borough.reset_index()
# Out:
#              month incident
# borough               BRONX BROOKLYN MANHATTAN QUEENS STATEN ISLAND
# 0            April     5296    10607      7415   9243          1228
# 1           August     5438    11360      7257   9793          1258
# 2         December     3797     7871      5237   7009          1138
# 3         February     4859     9662      6503   8562          1311
# 4          January     5253    10740      6855   9490          1474
# 5             July     5838    11916      7606  10509          1289
# 6             June     6153    12792      8261  10724          1429
# 7            March     5748    11610      7552  10013          1376
# 8              May     6193    12649      8304  10740          1381
# 9         November     4705     9694      6494   8691          1168
# 10         October     5526    11279      7649  10342          1358
# 11       September     5380    11107      7644   9722          1231

# %%
month_borough.columns = month_borough.columns.get_level_values(1)

# %%
month_borough
# Out:
# borough    BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# month
# April       5296     10607       7415    9243           1228
# August      5438     11360       7257    9793           1258
# December    3797      7871       5237    7009           1138
# February    4859      9662       6503    8562           1311
# January     5253     10740       6855    9490           1474
# July        5838     11916       7606   10509           1289
# June        6153     12792       8261   10724           1429
# March       5748     11610       7552   10013           1376
# May         6193     12649       8304   10740           1381
# November    4705      9694       6494    8691           1168
# October     5526     11279       7649   10342           1358
# September   5380     11107       7644    9722           1231

# %%
month_borough['month']=month_borough.index

# %%
month_borough.reset_index(inplace=True,drop=True)

# %%
month_borough
# Out:
# borough  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND      month
# 0         5296     10607       7415    9243           1228      April
# 1         5438     11360       7257    9793           1258     August
# 2         3797      7871       5237    7009           1138   December
# 3         4859      9662       6503    8562           1311   February
# 4         5253     10740       6855    9490           1474    January
# 5         5838     11916       7606   10509           1289       July
# 6         6153     12792       8261   10724           1429       June
# 7         5748     11610       7552   10013           1376      March
# 8         6193     12649       8304   10740           1381        May
# 9         4705      9694       6494    8691           1168   November
# 10        5526     11279       7649   10342           1358    October
# 11        5380     11107       7644    9722           1231  September

# %%
month_borough = month_borough[['month','BRONX','BROOKLYN','MANHATTAN','QUEENS' ,'STATEN ISLAND']]

# %%
month_borough['total_accidents'] = month_borough.sum(axis=1).astype(int)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
month_borough
# Out:
# borough      month  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND  \
# 0            April   5296     10607       7415    9243           1228
# 1           August   5438     11360       7257    9793           1258
# 2         December   3797      7871       5237    7009           1138
# 3         February   4859      9662       6503    8562           1311
# 4          January   5253     10740       6855    9490           1474
# 5             July   5838     11916       7606   10509           1289
# 6             June   6153     12792       8261   10724           1429
# 7            March   5748     11610       7552   10013           1376
# 8              May   6193     12649       8304   10740           1381
# 9         November   4705      9694       6494    8691           1168
# 10         October   5526     11279       7649   10342           1358
# 11       September   5380     11107       7644    9722           1231
#
# borough  total_accidents
# 0                  33789
# ...

# %%
month_borough.to_sql(name='month_borough', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from month_borough', con=engine).head()
# Out:
#       month  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND  \
# 0     April   5296     10607       7415    9243           1228
# 1    August   5438     11360       7257    9793           1258
# 2  December   3797      7871       5237    7009           1138
# 3  February   4859      9662       6503    8562           1311
# 4   January   5253     10740       6855    9490           1474
#
#    total_accidents
# 0            33789
# 1            35106
# 2            25052
# 3            30897
# 4            33812

# %%
weekday_borough = pd.pivot_table(df, values=['incident'], index=['day_of_week'],columns=['borough'],aggfunc=np.sum)

# %%
weekday_borough.reset_index()
# Out:
#         day_of_week incident
# borough                BRONX BROOKLYN MANHATTAN QUEENS STATEN ISLAND
# 0            Friday    10400    20826     14338  17884          2448
# 1            Monday     9384    19403     11500  16918          2227
# 2          Saturday     8654    16765     11544  15726          2141
# 3            Sunday     7221    15588      9757  13737          1648
# 4          Thursday     9676    19992     13750  17062          2404
# 5           Tuesday     9517    19551     12840  16691          2305
# 6         Wednesday     9334    19162     13048  16820          2468

# %%
weekday_borough.columns = weekday_borough.columns.get_level_values(1)

# %%
weekday_borough
# Out:
# borough      BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# day_of_week
# Friday       10400     20826      14338   17884           2448
# Monday        9384     19403      11500   16918           2227
# Saturday      8654     16765      11544   15726           2141
# Sunday        7221     15588       9757   13737           1648
# Thursday      9676     19992      13750   17062           2404
# Tuesday       9517     19551      12840   16691           2305
# Wednesday     9334     19162      13048   16820           2468

# %%
weekday_borough['weekday']=weekday_borough.index

# %%
weekday_borough.reset_index(inplace=True,drop=True)

# %%
weekday_borough
# Out:
# borough  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND    weekday
# 0        10400     20826      14338   17884           2448     Friday
# 1         9384     19403      11500   16918           2227     Monday
# 2         8654     16765      11544   15726           2141   Saturday
# 3         7221     15588       9757   13737           1648     Sunday
# 4         9676     19992      13750   17062           2404   Thursday
# 5         9517     19551      12840   16691           2305    Tuesday
# 6         9334     19162      13048   16820           2468  Wednesday

# %%
weekday_borough = weekday_borough[['weekday','BRONX','BROOKLYN','MANHATTAN','QUEENS','STATEN ISLAND']]

# %%
weekday_borough['total_accidents'] = weekday_borough.sum(axis=1).astype(int)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
weekday_borough
# Out:
# borough    weekday  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND  \
# 0           Friday  10400     20826      14338   17884           2448
# 1           Monday   9384     19403      11500   16918           2227
# 2         Saturday   8654     16765      11544   15726           2141
# 3           Sunday   7221     15588       9757   13737           1648
# 4         Thursday   9676     19992      13750   17062           2404
# 5          Tuesday   9517     19551      12840   16691           2305
# 6        Wednesday   9334     19162      13048   16820           2468
#
# borough  total_accidents
# 0                  65896
# 1                  59432
# 2                  54830
# 3                  47951
# 4                  62884
# 5                  60904
# 6                  60832

# %%
weekday_borough.to_sql(name='weekday_borough', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from weekday_borough', con=engine).head()
# Out:
#     weekday  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND  \
# 0    Friday  10400     20826      14338   17884           2448
# 1    Monday   9384     19403      11500   16918           2227
# 2  Saturday   8654     16765      11544   15726           2141
# 3    Sunday   7221     15588       9757   13737           1648
# 4  Thursday   9676     19992      13750   17062           2404
#
#    total_accidents
# 0            65896
# 1            59432
# 2            54830
# 3            47951
# 4            62884
